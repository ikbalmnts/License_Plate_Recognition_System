# %% [markdown]
# ##Yolov8 Plaka Tanıma Sistemi

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/License_Plate_Recognition_System/plate_detection
# Out:
# /content/drive/MyDrive/License_Plate_Recognition_System/plate_detection

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/License_Plate_Recognition_System/plate_detection'

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.19 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 28.9/78.2 GB disk)

# %%
# !yolo detect train data=/content/drive/MyDrive/License_Plate_Recognition_System/plate_detection/config.yaml model=yolov8n.pt epochs=100 patience=30 imgsz=640 workers=8 batch=12 device=0 name=yolov8s-plate_detection
# Out:
# Ultralytics YOLOv8.2.19 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo detect predict model=/content/drive/MyDrive/License_Plate_Recognition_System/plate_detection/runs/detect/yolov8s-plate_detection4/weights/best.pt source=/content/drive/MyDrive/License_Plate_Recognition_System/plate_detection/data/plate_dataset/images/train/10.jpg save=True
# Out:
# Ultralytics YOLOv8.2.19 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 /content/drive/MyDrive/License_Plate_Recognition_System/plate_detection/data/plate_dataset/images/train/10.jpg: 640x384 1 licence_plate, 110.7ms
# Speed: 3.8ms preprocess, 110.7ms inference, 1870.1ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
